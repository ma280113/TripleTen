# %% [markdown]
# # 🎓  Cómo usar IA para aprender más y mejor en tu camino hacia ser un profesional de los datos

# %% [markdown]
# 🧠 *Objetivos:*
# * Identificar cómo la IA puede apoyar el aprendizaje autónomo y activo de herramientas como pandas
# * Aplicar estrategias de prompting para obtener explicaciones, ejercicios y revisiones útiles en el proceso de wrangling de datos

# %% [markdown]
# <center>
#   <img src="https://github.com/zyntonyson/bootcamp_ds_da/blob/main/04-data-wrangling/img/title.png?raw=1" alt="IA para educación - Logo" style="max-width:50%; height:auto;"  width="25%">
# </center>

# %% [markdown]
# *Agenda: 60-90 min Revisaremos algunos escenarios donde el uso de IA puede potenciar tu tiempo de estudio*

# %% [markdown]
# ## 📚 *Durante el estudio en la plataforma*
#
# ---

# %% [markdown]
# **🎯 Escenario:** Explicación más simple de conceptos complejos
# 💬 *Prompt sugeridos:*
#
# > "Explícame en palabras simples qué hace `groupby().agg()` en pandas con un ejemplo"
# >> 💡 Tip: Comparaciones, analogías, ejemplos cotidianos.

# %% [markdown]
# **🎯 Escenario :** Entender errores
#
# 💬 *Prompt sugeridos:*
#
# ![](https://github.com/zyntonyson/bootcamp_ds_da/blob/main/04-data-wrangling/img/error.png?raw=1)

# %% [markdown]
# ![](https://github.com/zyntonyson/bootcamp_ds_da/blob/main/04-data-wrangling/img/error_2.png?raw=1)

# %% [markdown]
# ![](https://github.com/zyntonyson/bootcamp_ds_da/blob/main/04-data-wrangling/img/error_3.png?raw=1)

# %% [markdown]
# **🎯 Escenario:** Resumen del tema
# 💬 *Prompt sugerido:*
# "Resúmeme en 5 bullets las operaciones más comunes de wrangling con pandas" ( O usa el resumen del tema)

# %% [markdown]
# **🎯 Escenario:** Crear cuestionarios o ejercicios
# 💬 *Prompt sugerido:*
# - "Crea un quiz de 5 preguntas sobre filtrado de datos con `.loc`"
#
# - "Creame un ejercicio para practicas las tablas groupby en pandas, me gustaria que sea sobre el consumo de coca-cola"
#
# >> 💡 Tip: Pedirlos con dificultad progresiva.

# %% [markdown]
# ## 🛠️ *Al resolver un proyecto de unidad*
#
# ---

# %% [markdown]
# **🎯 Escenario:** Instrucciones poco claras
# 💬 *Prompt sugerido:*  ¿Qué significará duplicado engañoso?

# %% [markdown]
# ![](https://github.com/zyntonyson/bootcamp_ds_da/blob/main/04-data-wrangling/img/item_to_explain.png?raw=1)

# %% [markdown]
# **🎯 Escenario:** Proponer plan de resolución
# 💬 *Prompt sugerido:* Ayudame a resolver este ejercicio, quiero comprender lo que se me pide cómo resolverlo

# %% [markdown]
# ![](https://github.com/zyntonyson/bootcamp_ds_da/blob/main/04-data-wrangling/img/item_to_explain_2.png?raw=1)

# %% [markdown]
# **🎯 Escenario:** Revisión previa al envío
# 💬 *Prompt sugerido:*
# "Revísame mi proyecto y dime si hay algo que mejorar antes de entregarlo"

# %% [markdown]
# ## 🔁 *Después de entregar el proyecto*
#
# ----

# %% [markdown]
# **🎯 Escenario:** Entender comentarios del revisor
# 💬 *Prompt sugerido:*
# "No entiendo del todo que es lo que se me pide corregir, podrias explicarme y darme un ejemplo guiado"
#
# ![](https://github.com/zyntonyson/bootcamp_ds_da/blob/main/04-data-wrangling/img/comentario_revisor.png?raw=1)
#
#
#
# **🎯 Escenario 3:** Revisión final antes de reenviar
# 💬 *Prompt sugerido:*
# "¿Puedes revisar si esta nueva solución cumple con lo que pedía el revisor?"

# %% [markdown]
# ## 🔁 *Repaso y autoevaluación*

# %% [markdown]
# ---
#
#
# **🎯 Escenario 1:** Resumen desde transcripciones de clase
# 💬 *Prompt sugerido:*
# - Resumen sobre la clase
# - Cuales son los temas de mayor dificultad
# - Buscar momentos especificos
# - Pedir cuestionario
#
#
# **🎯 Escenario 3:** Quiz a partir de mis notas
#
# ![](https://github.com/zyntonyson/bootcamp_ds_da/blob/main/04-data-wrangling/img/b03dbd3955627decd35245eeb967c0a0.jpg?raw=1)
#
# 💬 *Prompt sugerido:*
# "Con mis notas de pandas, hazme una trivia de 3 preguntas con opciones y la respuesta correcta"

# %% [markdown]
# Este tipo de tecnologias pueden ayudarte para aprovechar a lo máximo tu tiempo tiempo de estudio:
#
# - [NotebookLLM convierte tus notas en un podcast (Disponible por ahora en inglés)](https://notebooklm.google.com/)
# - [Dale voz a tus notas](https://platform.hume.ai/)
# - [Convierte tus notas en canciones](https://suno.com/)
# - [Crea flashcards con tus notas](https://ankiweb.net/)
# - [Crea cuestionarios interactivos](https://kahoot.com/)

# %% [markdown]
# ---
#
# ✨ *Ideas clave para llevarte de esta sesión:*
# 1. La IA puede explicarte, retarte y corregirte como un tutor personalizado 24/7 🤖
# 2. Un buen *prompt* es claro, con contexto y pide justo lo que necesitas
# 3. No se trata de que la IA lo haga por ti, sino de que aprendas más rápido y con más confianza 💪
# 4. Tu pensamiento crítico y práctica siguen siendo el ingrediente principal del aprendizaje 🧠
#
# ¡Haz de la IA tu aliada para convertirte en un gran analista de datos! 🐼🚀

# %% [markdown]
# >> “La IA no viene a hacer tu trabajo, viene a multiplicar tu capacidad de aprender y crear 🚀”

# %% [markdown]
# ---
#
# ## 🚀 Para seguir aprendiendo :
#
# - 📚 Vuelve a revisar este notebook junto con la grabación y ¡anímate a intentar con la sugerencias proporcionadas!
# - 💬 Recuerda que en Discord puedes dejar todos tus comentarios y dudas sobre el contenido del sprint en [Sprint 4](https://discord.com/channels/1081207584104656986/1270073640553021482).
#     - 📝 Si tienes preguntas sobre tu proyecto, usa el canal `#project` para recibir ayuda y compartir ideas.
#     - 🤝 Aprovecha el espacio de `CoLearning` para aclarar tus dudas junto con otros estudiantes e instructores: [Co-Learning](https://discord.com/channels/1081207584104656986/1197953851391746119).
# - 📅 ¿Necesitas ayuda personalizada? Puedes agendar una sesión `1:1` conmigo aquí: [1:1 Roman Castillo](https://scheduler.zoom.us/roman-castillo/1-1-roman-castillo).
#
# ¡Sigue practicando y no dudes en pedir apoyo cuando lo necesites! 💪✨
